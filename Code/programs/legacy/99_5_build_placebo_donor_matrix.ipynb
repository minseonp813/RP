# %% [markdown]
# # Build placebo donor matrix
# Run the cells below from the `Code` folder. Completed chunks are reused unless `PLACEBO_OVERWRITE_CHUNKS` is set to `1`.

# %%
from pathlib import Path
import os

package_dir = Path.cwd()
script = package_dir / "99_5_build_placebo_donor_matrix.py"
if not script.is_file():
    raise FileNotFoundError(f"Open this notebook from the Code folder: {script}")

os.environ["PLACEBO_MATRIX_WORKERS"] = "1"
os.environ["PLACEBO_OVERWRITE_CHUNKS"] = "0"
script
# Out:
# WindowsPath('C:/Users/hahn0/RP/Replication_Package/99_5_build_placebo_donor_matrix.py')

# %%
from time import perf_counter
timer_start = perf_counter()
# %run ./99_5_build_placebo_donor_matrix.py
elapsed_seconds = perf_counter() - timer_start
print(f"Total elapsed time: {int(elapsed_seconds // 3600):02d}:{int((elapsed_seconds % 3600) // 60):02d}:{elapsed_seconds % 60:05.2f}")
# Out:
# [resume] donor_matrix_chunk_0000.csv
# [resume] donor_matrix_chunk_0001.csv
# [resume] donor_matrix_chunk_0002.csv
# [resume] donor_matrix_chunk_0003.csv
# [resume] donor_matrix_chunk_0004.csv
# [resume] donor_matrix_chunk_0005.csv
# [resume] donor_matrix_chunk_0006.csv
# [resume] donor_matrix_chunk_0007.csv
# [resume] donor_matrix_chunk_0008.csv
# [resume] donor_matrix_chunk_0009.csv
# [resume] donor_matrix_chunk_0010.csv
# [resume] donor_matrix_chunk_0011.csv
# [resume] donor_matrix_chunk_0012.csv
# [resume] donor_matrix_chunk_0013.csv
# [resume] donor_matrix_chunk_0014.csv
# [resume] donor_matrix_chunk_0015.csv
# [resume] donor_matrix_chunk_0016.csv
# [resume] donor_matrix_chunk_0017.csv
# [resume] donor_matrix_chunk_0018.csv
# [resume] donor_matrix_chunk_0019.csv
# [resume] donor_matrix_chunk_0020.csv
# [resume] donor_matrix_chunk_0021.csv
# [resume] donor_matrix_chunk_0022.csv
# [resume] donor_matrix_chunk_0023.csv
# [resume] donor_matrix_chunk_0024.csv
# ...
